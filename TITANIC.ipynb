# %%
import pandas as pd
import warnings as w
w.filterwarnings("ignore")
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
input=df.drop(columns=['PassengerId','Survived' ,'Name','SibSp','Parch','Ticket','Cabin' ,'Embarked'])
output=df["Survived"]

# %%
decode=LabelEncoder()
input["Sex"] = decode.fit_transform(input["Sex"])
input
# Out:
#      Pclass  Sex   Age     Fare
# 0         3    1  22.0   7.2500
# 1         1    0  38.0  71.2833
# 2         3    0  26.0   7.9250
# 3         1    0  35.0  53.1000
# 4         3    1  35.0   8.0500
# ..      ...  ...   ...      ...
# 886       2    1  27.0  13.0000
# 887       1    0  19.0  30.0000
# 888       3    0   NaN  23.4500
# 889       1    1  26.0  30.0000
# 890       3    1  32.0   7.7500
#
# [891 rows x 4 columns]

# %%
input_a
# Out:
#      Pclass   Age     Fare
# 0         3  22.0   7.2500
# 1         1  38.0  71.2833
# 2         3  26.0   7.9250
# 3         1  35.0  53.1000
# 4         3  35.0   8.0500
# ..      ...   ...      ...
# 886       2  27.0  13.0000
# 887       1  19.0  30.0000
# 888       3   NaN  23.4500
# 889       1  26.0  30.0000
# 890       3  32.0   7.7500
#
# [891 rows x 3 columns]

# %%
input_a = input.drop(columns=["Sex"])
input_a.isnull().sum()
# Out:
# Pclass    0
# Age       0
# Fare      0
# dtype: int64

# %%
input["Age"].fillna(0, inplace =True)

# %%
input_a.isnull().sum()
# Out:
# Pclass    0
# Age       0
# Fare      0
# dtype: int64

# %%
input_a_train, input_a_test, output_train, output_test = train_test_split(input_a, output, train_size=0.8)
model = DecisionTreeClassifier()
model.fit(input_a_train, output_train)
predictions = model.predict(input_a_test)

# %%
print("The Accuracy is  ",int ((model.score(input_a_train,output_train))*100),'%')
# Out:
# The Accuracy is   95 %
